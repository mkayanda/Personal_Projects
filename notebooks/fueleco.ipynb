# %% [markdown]
# ### We are going to use a dataset from www.fueleconomy.gov that provides information about makes and models of cars from 1984 through 2018.

# %%
import pandas as pd 
import numpy as np

# %%
fueleco = pd.read_csv("../data/vehicles.csv.zip")
fueleco.head()
# Out:
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  15.695714         0.0        0.0        0.0      19      0.0        0
# 1  29.964545         0.0        0.0        0.0       9      0.0        0
# 2  12.207778         0.0        0.0        0.0      23      0.0        0
# 3  29.964545         0.0        0.0        0.0      10      0.0        0
# 4  17.347895         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                       createdOn                    modifiedOn  startStop  \
# ...

# %%
#Call individual summary statistics methods such as .mean, .std, and .quantile

fueleco.mean()
# Out:
# barrels08             17.442712
# barrelsA08             0.219276
# charge120              0.000000
# charge240              0.029630
# city08                18.077799
# city08U                5.040648
# cityA08                0.569883
# cityA08U               0.416097
# cityCD                 0.000560
# cityE                  0.225181
# cityUF                 0.000975
# co2                   72.538989
# co2A                   5.543950
# co2TailpipeAGpm       17.826864
# co2TailpipeGpm       470.704841
# comb08                20.323828
# comb08U                5.652724
# combA08                0.631160
# combA08U               0.453725
# combE                  0.230912
# combinedCD             0.000459
# combinedUF             0.000959
# cylinders              5.729105
# displ                  3.309829
# engId               8582.377382
# feScore                0.122580
# fuelCost08          2242.470781
# fuelCostA08           91.335260
# ghgScore               0.120866
# ...

# %%
fueleco.std()
# Out:
# barrels08              4.580230
# barrelsA08             1.143837
# charge120              0.000000
# charge240              0.487408
# city08                 6.970672
# city08U               10.462790
# cityA08                4.297124
# cityA08U               4.093495
# cityCD                 0.045392
# cityE                  3.180894
# cityUF                 0.022785
# co2                  163.252019
# co2A                  55.956932
# co2TailpipeAGpm       93.937414
# co2TailpipeGpm       122.351021
# comb08                 6.882807
# comb08U               11.231748
# combA08                4.395797
# combA08U               4.131767
# combE                  3.244463
# combinedCD             0.040759
# combinedUF             0.022392
# cylinders              1.754487
# displ                  1.361925
# engId              17606.675590
# feScore                2.516348
# fuelCost08           601.273869
# fuelCostA08          479.485802
# ghgScore               2.512612
# ...

# %%
fueleco.quantile([0, 0.25, 0.5, 0.75, 1]).T
# Out:
#                      0.00         0.25          0.50          0.75  \
# barrels08            0.06    14.330870     17.347895     20.115000
# barrelsA08           0.00     0.000000      0.000000      0.000000
# charge120            0.00     0.000000      0.000000      0.000000
# charge240            0.00     0.000000      0.000000      0.000000
# city08               6.00    15.000000     17.000000     20.000000
# city08U              0.00     0.000000      0.000000      0.000000
# cityA08              0.00     0.000000      0.000000      0.000000
# cityA08U             0.00     0.000000      0.000000      0.000000
# cityCD               0.00     0.000000      0.000000      0.000000
# cityE                0.00     0.000000      0.000000      0.000000
# cityUF               0.00     0.000000      0.000000      0.000000
# co2                 -1.00    -1.000000     -1.000000     -1.000000
# co2A                -1.00    -1.000000     -1.000000     -1.000000
# ...

# %%
# Call the .describe method:
fueleco.describe().T
# Out:
#                    count          mean           std       min          25%  \
# barrels08        39101.0     17.442712      4.580230      0.06    14.330870
# barrelsA08       39101.0      0.219276      1.143837      0.00     0.000000
# charge120        39101.0      0.000000      0.000000      0.00     0.000000
# charge240        39101.0      0.029630      0.487408      0.00     0.000000
# city08           39101.0     18.077799      6.970672      6.00    15.000000
# city08U          39101.0      5.040648     10.462790      0.00     0.000000
# cityA08          39101.0      0.569883      4.297124      0.00     0.000000
# cityA08U         39101.0      0.416097      4.093495      0.00     0.000000
# cityCD           39101.0      0.000560      0.045392      0.00     0.000000
# cityE            39101.0      0.225181      3.180894      0.00     0.000000
# cityUF           39101.0      0.000975      0.022785      0.00     0.000000
# ...

# %%
# check summary statistics of object columns
fueleco.describe(include=object)
# Out:
#                     drive eng_dscr fuelType         fuelType1       make  \
# count               37912    23431    39101             39101      39101
# unique                  7      545       14                 6        134
# top     Front-Wheel Drive    (FFS)  Regular  Regular Gasoline  Chevrolet
# freq                13653     8827    25620             26931       3900
#
#                   model mpgData            trany        VClass guzzler  ...  \
# count             39101   39101            39090         39101    2335  ...
# unique             3816       2               37            34       3  ...
# top     F150 Pickup 2WD       N  Automatic 4-spd  Compact Cars       G  ...
# freq                214   26400            11045          5661    1356  ...
#
#        atvType fuelType2 rangeA     evMotor mfrCode          c240Dscr  \
# count     3204      1490   1485         644    8289                53
# unique       8         4    216         125      46                 5
# ...

# %%
# Column Type
fueleco.dtypes
# Out:
# barrels08     float64
# barrelsA08    float64
# charge120     float64
# charge240     float64
# city08          int64
#                ...
# modifiedOn     object
# startStop      object
# phevCity        int64
# phevHwy         int64
# phevComb        int64
# Length: 83, dtype: object

# %%
#summry of dtypes
fueleco.dtypes.value_counts()
# Out:
# float64    32
# int64      27
# object     23
# bool        1
# dtype: int64

# %%
# we could save memry space by: 
fueleco.select_dtypes("int64").describe().T
# Out:
#                 count          mean           std      min     25%      50%  \
# city08        39101.0     18.077799      6.970672      6.0    15.0     17.0
# cityA08       39101.0      0.569883      4.297124      0.0     0.0      0.0
# co2           39101.0     72.538989    163.252019     -1.0    -1.0     -1.0
# co2A          39101.0      5.543950     55.956932     -1.0    -1.0     -1.0
# comb08        39101.0     20.323828      6.882807      7.0    17.0     20.0
# combA08       39101.0      0.631160      4.395797      0.0     0.0      0.0
# engId         39101.0   8582.377382  17606.675590      0.0     0.0    202.0
# feScore       39101.0      0.122580      2.516348     -1.0    -1.0     -1.0
# fuelCost08    39101.0   2242.470781    601.273869    500.0  1850.0   2250.0
# fuelCostA08   39101.0     91.335260    479.485802      0.0     0.0      0.0
# ghgScore      39101.0      0.120866      2.512612     -1.0    -1.0     -1.0
# ...
